# %%
import sys
sys.path.append("..")
import pickle

# %%
from games.abstract_poker_additional import AbstractPokerRootChanceGameState
from games.algorithms import ChanceSamplingCFR, VanillaCFR
from common.constants import card_dealing, results_map
import numpy as np
import pandas as pd

# %%
# Hyperparameters
_MAX_HAND_STRENGTH = 10
_MAX_TURNS = 3
_NUM_TRAIN_ITERS = 100_000
_ANTE_SIZE = 1

# %%
# card_dealing(_MAX_HAND_STRENGTH)

# %% [markdown]
# # Train

# %%
root = AbstractPokerRootChanceGameState(max_hand_strength = _MAX_HAND_STRENGTH,
                                    max_turns = _MAX_TURNS,
                                    ante = _ANTE_SIZE,
                                    report = False)
chance_sampling_cfr = ChanceSamplingCFR(root)
chance_sampling_cfr.run(iterations = _NUM_TRAIN_ITERS)
chance_sampling_cfr.compute_nash_equilibrium()

    # vanilla cfr
#     vanilla_cfr_g3 = VanillaCFR(root)
#     vanilla_cfr_g3.run(iterations = _NUM_TRAIN_ITERS)
#     vanilla_cfr_g3.compute_nash_equilibrium()

# %%
chance_sampling_cfr.nash_equilibrium
# Out:
# {'.': {'1.1': 0.01,
#   '1.2': 0.01,
#   '1.3': 0.01,
#   '1.4': 0.01,
#   '1.5': 0.01,
#   '1.6': 0.01,
#   '1.7': 0.01,
#   '1.8': 0.01,
#   '1.9': 0.01,
#   '1.10': 0.01,
#   '2.1': 0.01,
#   '2.2': 0.01,
#   '2.3': 0.01,
#   '2.4': 0.01,
#   '2.5': 0.01,
#   '2.6': 0.01,
#   '2.7': 0.01,
#   '2.8': 0.01,
#   '2.9': 0.01,
#   '2.10': 0.01,
#   '3.1': 0.01,
#   '3.2': 0.01,
#   '3.3': 0.01,
#   '3.4': 0.01,
#   '3.5': 0.01,
#   '3.6': 0.01,
#   '3.7': 0.01,
#   '3.8': 0.01,
#   '3.9': 0.01,
#   '3.10': 0.01,
#   '4.1': 0.01,
#   '4.2': 0.01,
#   '4.3': 0.01,
#   '4.4': 0.01,
#   '4.5': 0.01,
#   '4.6': 0.01,
#   '4.7': 0.01,
#   '4.8': 0.01,
#   '4.9': 0.01,
#   '4.10': 0.01,
#   '5.1': 0.01,
#   '5.2': 0.01,
#   '5.3': 0.01,
#   '5.4': 0.01,
#   '5.5': 0.01,
#   '5.6': 0.01,
#   '5.7': 0.01,
#   '5.8': 0.01,
#   '5.9': 0.01,
#   '5.10': 0.01,
#   '6.1': 0.01,
#   '6.2': 0.01,
#   '6.3': 0.01,
#   '6.4': 0.01,
#   '6.5': 0.01,
#   '6.6': 0.01,
#   '6.7': 0.01,
#   '6.8': 0.01,
#   '6.9': 0.01,
#   '6.10': 0.01,
#   '7.1': 0.01,
#   '7.2': 0.01,
#   '7.3': 0.01,
#   '7.4': 0.01,
#   '7.5': 0.01,
#   '7.6': 0.01,
#   '7.7': 0.01,
#   '7.8': 0.01,
#   '7.9': 0.01,
#   '7.10': 0.01,
#   '8.1': 0.01,
#   '8.2': 0.01,
#   '8.3': 0.01,
#   '8.4': 0.01,
#   '8.5': 0.01,
#   '8.6': 0.01,
#   '8.7': 0.01,
#   '8.8': 0.01,
#   '8.9': 0.01,
#   '8.10': 0.01,
#   '9.1': 0.01,
#   '9.2': 0.01,
#   '9.3': 0.01,
#   '9.4': 0.01,
#   '9.5': 0.01,
#   '9.6': 0.01,
#   '9.7': 0.01,
#   '9.8': 0.01,
#   '9.9': 0.01,
#   '9.10': 0.01,
#   '10.1': 0.01,
#   '10.2': 0.01,
#   '10.3': 0.01,
#   '10.4': 0.01,
#   '10.5': 0.01,
#   '10.6': 0.01,
#   '10.7': 0.01,
#   '10.8': 0.01,
#   '10.9': 0.01,
#   '10.10': 0.01},
#  '.1.': {'BET': 0.13402606544928816,
#   'CHECK_INITIATE': 0.8659408033178987,
#   'ALL-IN': 3.3131232813172954e-05},
#  '.1.BET': {'CALL': 0.006066377859056389,
#   'FOLD': 0.9876500725416156,
#   'RAISE': 0.006179825147027249,
#   'RAISE-ALL-IN': 0.00010372445230067643},
#  '.1.BET.CALL': {'BET': 0.26875605879620407,
#   'CHECK_INITIATE': 0.7311615412300742,
#   'ALL-IN': 8.239997372180052e-05},
#  '.1.BET.CALL.BET': {'CALL': 0.09699707542485062,
#   'FOLD': 0.8372220683756592,
#   'RAISE': 0.03442963831005739,
#   'RAISE-ALL-IN': 0.03135121788943284},
#  '.1.BET.CALL.BET.CALL': {'BET': 0.34292952887817035,
#   'CHECK_INITIATE': 0.45946984922747697,
#   'ALL-IN': 0.1976006218943528},
#  '.1.BET.CALL.BET.CALL.BET': {'CALL': 0.08713969394165545,
#   'FOLD': 0.7576342901292901,
#   'RAISE': 0.07875806600340869,
#   'RAISE-ALL-IN': 0.07646794992564568},
#  '.1.BET.CALL.BET.CALL.BET.CALL': {},
#  '.1.BET.CALL.BET.CALL.BET.FOLD': {},
#  '.1.BET.CALL.BET.CALL.BET.RAISE': {'CALL': 0.001279564981262174,
#   'FOLD': 0.9986210956451226,
#   'RAISE-ALL-IN': 9.933937361528019e-05},
#  '.1.BET.CALL.BET.CALL.BET.RAISE.CALL': {},
#  '.1.BET.CALL.BET.CALL.BET.RAISE.FOLD': {},
#  '.1.BET.CALL.BET.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.03278068734097634,
#   'FOLD': 0.9672193126590236},
#  '.1.BET.CALL.BET.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.BET.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.BET.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0001490090604229203,
#   'FOLD': 0.9998509909395771},
#  '.1.BET.CALL.BET.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.BET.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE': {'BET': 0.2937772949591981,
#   'CHECK_RESPONSE': 0.0035257413387683543,
#   'ALL-IN': 0.7026969637020336},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.000617628699317417,
#   'FOLD': 0.9989639754583779,
#   'RAISE': 0.00022266267208093915,
#   'RAISE-ALL-IN': 0.00019573317022390658},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.20078473170261965,
#   'FOLD': 0.34950897766945976,
#   'RAISE-ALL-IN': 0.44970629062792056},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.4395284768538941,
#   'FOLD': 0.5604715231461058},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.01457584303912279,
#   'FOLD': 0.9854241569608772},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 0.0001112142765740265,
#   'FOLD': 0.9998887857234261},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.BET.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.BET.CALL.BET.CALL.ALL-IN': {'CALL-ALL-IN': 0.010326974148950879,
#   'FOLD': 0.9896730258510491},
#  '.1.BET.CALL.BET.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.BET.CALL.ALL-IN.FOLD': {},
#  '.1.BET.CALL.BET.FOLD': {},
#  '.1.BET.CALL.BET.RAISE': {'CALL': 0.15005529156292632,
#   'FOLD': 0.8498425092232949,
#   'RAISE-ALL-IN': 0.00010219921377882166},
#  '.1.BET.CALL.BET.RAISE.CALL': {'BET': 0.9995459486401562,
#   'CHECK_INITIATE': 0.00022702567992182175,
#   'ALL-IN': 0.00022702567992182175},
#  '.1.BET.CALL.BET.RAISE.CALL.BET': {'CALL': 0.15414179877705306,
#   'FOLD': 0.047823506008908126,
#   'RAISE': 0.2420547681937145,
#   'RAISE-ALL-IN': 0.5559799270203244},
#  '.1.BET.CALL.BET.RAISE.CALL.BET.CALL': {},
#  '.1.BET.CALL.BET.RAISE.CALL.BET.FOLD': {},
#  '.1.BET.CALL.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.3789286712634494,
#   'FOLD': 0.6209956191338619,
#   'RAISE-ALL-IN': 7.570960268866126e-05},
#  '.1.BET.CALL.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.1.BET.CALL.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.1.BET.CALL.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.05936923352559481,
#   'FOLD': 0.9406307664744051},
#  '.1.BET.CALL.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.BET.RAISE.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.00011356440403299189,
#   'FOLD': 0.999886435595967},
#  '.1.BET.CALL.BET.RAISE.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.BET.RAISE.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.2792993324414114,
#   'CHECK_RESPONSE': 0.6126026862978589,
#   'ALL-IN': 0.1080979812607296},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 0.25,
#   'FOLD': 0.25,
#   'RAISE': 0.25,
#   'RAISE-ALL-IN': 0.25},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.3717719082317685,
#   'FOLD': 0.5098444429883532,
#   'RAISE-ALL-IN': 0.11838364877987832},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.5,
#   'FOLD': 0.5},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0686031288045458,
#   'FOLD': 0.9313968711954542},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 0.5,
#   'FOLD': 0.5},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.BET.CALL.BET.RAISE.CALL.ALL-IN': {'CALL-ALL-IN': 0.05748242423550542,
#   'FOLD': 0.9425175757644945},
#  '.1.BET.CALL.BET.RAISE.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.BET.RAISE.CALL.ALL-IN.FOLD': {},
#  '.1.BET.CALL.BET.RAISE.FOLD': {},
#  '.1.BET.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.05748242423550542,
#   'FOLD': 0.9425175757644945},
#  '.1.BET.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.00015329882066823257,
#   'FOLD': 0.9998467011793318},
#  '.1.BET.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE': {'BET': 0.8749988093278461,
#   'CHECK_RESPONSE': 0.12021229952977261,
#   'ALL-IN': 0.0047888911423812144},
#  '.1.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.005342561068188767,
#   'FOLD': 0.9816920606350323,
#   'RAISE': 0.012879650559107858,
#   'RAISE-ALL-IN': 8.572773767110985e-05},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL': {'BET': 0.9893025415367974,
#   'CHECK_INITIATE': 0.005348729231601356,
#   'ALL-IN': 0.005348729231601356},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.BET': {'CALL': 0.01225612760585531,
#   'FOLD': 0.01826739971085775,
#   'RAISE': 0.013764291581127732,
#   'RAISE-ALL-IN': 0.9557121811021592},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.BET.CALL': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.BET.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE': {'CALL': 0.0018021885813590652,
#   'FOLD': 0.996395622837282,
#   'RAISE-ALL-IN': 0.0018021885813590652},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.04970312005976412,
#   'FOLD': 0.9502968799402358},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0027032828720385976,
#   'FOLD': 0.9972967171279614},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE': {'BET': 0.012967651874251692,
#   'CHECK_RESPONSE': 0.9781666065240756,
#   'ALL-IN': 0.00886574160167277},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.25,
#   'FOLD': 0.25,
#   'RAISE': 0.25,
#   'RAISE-ALL-IN': 0.25},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.4263462880247671,
#   'FOLD': 0.5267590239980733,
#   'RAISE-ALL-IN': 0.04689468797715944},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.5,
#   'FOLD': 0.5},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.07034203196573917,
#   'FOLD': 0.9296579680342608},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 0.5,
#   'FOLD': 0.5},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.ALL-IN': {'CALL-ALL-IN': 0.0027365129479775697,
#   'FOLD': 0.9972634870520224},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL.ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.0047225287025512205,
#   'FOLD': 0.9855174598154458,
#   'RAISE-ALL-IN': 0.009760011482002924},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {'BET': 0.12346911715909303,
#   'CHECK_INITIATE': 0.8743121958954893,
#   'ALL-IN': 0.0022186869454178734},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET': {'CALL': 0.0965765419452521,
#   'FOLD': 0.0965765419452521,
#   'RAISE': 0.10290176249169004,
#   'RAISE-ALL-IN': 0.7039451536178056},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.CALL': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.11856922380791197,
#   'FOLD': 0.8754409195205906,
#   'RAISE-ALL-IN': 0.005989856671497428},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.4692657327081801,
#   'FOLD': 0.5307342672918199},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.008984785007246143,
#   'FOLD': 0.9910152149927538},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.20723774157650557,
#   'CHECK_RESPONSE': 0.12876872259366948,
#   'ALL-IN': 0.6639935358298248},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 0.12833666013039471,
#   'FOLD': 0.8620558972549828,
#   'RAISE': 0.008973033373897663,
#   'RAISE-ALL-IN': 0.0006344092407247756},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.2986853200187769,
#   'FOLD': 0.3289251529500893,
#   'RAISE-ALL-IN': 0.3723895270311338},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.035350879367631496,
#   'FOLD': 0.9646491206323685},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.31067874416623137,
#   'FOLD': 0.6893212558337686},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 0.0012688184814495507,
#   'FOLD': 0.9987311815185503},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.ALL-IN': {'CALL-ALL-IN': 0.19315308389050426,
#   'FOLD': 0.8068469161094958},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL.ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0033280304181268097,
#   'FOLD': 0.9966719695818732},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0027365129479775697,
#   'FOLD': 0.9972634870520224},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {'BET': 0.03070311898384121,
#   'CHECK_INITIATE': 0.9683201808474553,
#   'ALL-IN': 0.0009767001687035208},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET': {'CALL': 0.0028448553093382042,
#   'FOLD': 0.42758481584665803,
#   'RAISE': 0.4182244841411458,
#   'RAISE-ALL-IN': 0.15134584470285795},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.CALL': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE': {'CALL': 0.007029321786528923,
#   'FOLD': 0.009039235853298926,
#   'RAISE-ALL-IN': 0.9839314423601722},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.CALL': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0034011104289844722,
#   'FOLD': 0.9965988895710156},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0018614338544612277,
#   'FOLD': 0.9981385661455388},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE': {'BET': 0.8316173117302962,
#   'CHECK_RESPONSE': 0.003793140412450938,
#   'ALL-IN': 0.16458954785725285},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET': {'CALL': 0.003624192627148942,
#   'FOLD': 0.9830688813355913,
#   'RAISE': 0.0005607101678698374,
#   'RAISE-ALL-IN': 0.012746215869389902},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE': {'CALL': 0.4535846609830422,
#   'FOLD': 0.5448949520316835,
#   'RAISE-ALL-IN': 0.0015203869852744244},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.02631556494022057,
#   'FOLD': 0.9736844350597794},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.002280580477911636,
#   'FOLD': 0.9977194195220883},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 5.902161934088274e-05,
#   'FOLD': 0.9999409783806592},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.ALL-IN': {'CALL-ALL-IN': 0.005689710618676407,
#   'FOLD': 0.9943102893813236},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE.ALL-IN.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 5.634867883174928e-05,
#   'FOLD': 0.9999436513211682},
#  '.1.BET.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.BET.CALL.ALL-IN': {'CALL-ALL-IN': 0.005472864339511272,
#   'FOLD': 0.9945271356604887},
#  '.1.BET.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.CALL.ALL-IN.FOLD': {},
#  '.1.BET.FOLD': {},
#  '.1.BET.RAISE': {'CALL': 0.2745378825192911,
#   'FOLD': 0.725379717506987,
#   'RAISE-ALL-IN': 8.239997372180057e-05},
#  '.1.BET.RAISE.CALL': {'BET': 0.19976555329545878,
#   'CHECK_INITIATE': 0.8001343998270203,
#   'ALL-IN': 0.00010004687752094451},
#  '.1.BET.RAISE.CALL.BET': {'CALL': 0.07082945329556099,
#   'FOLD': 0.8302158341833217,
#   'RAISE': 0.06725103401353305,
#   'RAISE-ALL-IN': 0.031703678507584376},
#  '.1.BET.RAISE.CALL.BET.CALL': {'BET': 0.8231305193528787,
#   'CHECK_INITIATE': 0.15348093285797346,
#   'ALL-IN': 0.02338854778914805},
#  '.1.BET.RAISE.CALL.BET.CALL.BET': {'CALL': 0.26745999737997495,
#   'FOLD': 0.2758645992470289,
#   'RAISE': 0.2830607579149773,
#   'RAISE-ALL-IN': 0.17361464545801877},
#  '.1.BET.RAISE.CALL.BET.CALL.BET.CALL': {},
#  '.1.BET.RAISE.CALL.BET.CALL.BET.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.CALL.BET.RAISE': {'CALL': 0.03924984642264781,
#   'FOLD': 0.9076237233491483,
#   'RAISE-ALL-IN': 0.0531264302282039},
#  '.1.BET.RAISE.CALL.BET.CALL.BET.RAISE.CALL': {},
#  '.1.BET.RAISE.CALL.BET.CALL.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.02616142703288909,
#   'FOLD': 0.973838572967111},
#  '.1.BET.RAISE.CALL.BET.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.BET.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.00010140584341175472,
#   'FOLD': 0.9998985941565883},
#  '.1.BET.RAISE.CALL.BET.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.BET.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE': {'BET': 0.08373039172243964,
#   'CHECK_RESPONSE': 0.040034732528515186,
#   'ALL-IN': 0.8762348757490452},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.005677753068946417,
#   'FOLD': 0.7029886587556119,
#   'RAISE': 0.2910616643507729,
#   'RAISE-ALL-IN': 0.0002719238246687462},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.19902904040534214,
#   'FOLD': 0.28143833191648543,
#   'RAISE-ALL-IN': 0.5195326276781724},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.00046712408051964767,
#   'FOLD': 0.9995328759194804},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.11792250837051574,
#   'FOLD': 0.8820774916294842},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 0.0005438476493374924,
#   'FOLD': 0.9994561523506625},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.BET.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.CALL.ALL-IN': {'CALL-ALL-IN': 0.029621093456267823,
#   'FOLD': 0.9703789065437322},
#  '.1.BET.RAISE.CALL.BET.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.BET.CALL.ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.07270448279482908,
#   'FOLD': 0.9253360677862238,
#   'RAISE-ALL-IN': 0.00195944941894704},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL': {'BET': 0.827779690161031,
#   'CHECK_INITIATE': 0.17145492608871246,
#   'ALL-IN': 0.0007653837502563694},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.BET': {'CALL': 0.31005623179037484,
#   'FOLD': 0.23062381308713992,
#   'RAISE': 0.06670621695046235,
#   'RAISE-ALL-IN': 0.392613738172023},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.BET.CALL': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.BET.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.4347885884973048,
#   'FOLD': 0.21653066572356203,
#   'RAISE-ALL-IN': 0.3486807457791332},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.11692024235853639,
#   'FOLD': 0.8830797576414636},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0004623112643096355,
#   'FOLD': 0.9995376887356904},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.3800249189200127,
#   'CHECK_RESPONSE': 0.47033789291560796,
#   'ALL-IN': 0.14963718816437926},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 0.0011160130649444746,
#   'FOLD': 0.5803673967791819,
#   'RAISE': 0.41740057709092915,
#   'RAISE-ALL-IN': 0.0011160130649444746},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.44361502111506707,
#   'FOLD': 0.5381421820708389,
#   'RAISE-ALL-IN': 0.018242796814094075},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0013368609510826758,
#   'FOLD': 0.9986631390489173},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.02736419522114112,
#   'FOLD': 0.9726358047788589},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 0.0022320261298889492,
#   'FOLD': 0.997767973870111},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.ALL-IN': {'CALL-ALL-IN': 0.03119722821067666,
#   'FOLD': 0.9688027717893234},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL.ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.03119722821067666,
#   'FOLD': 0.9688027717893234},
#  '.1.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.00025041073365880163,
#   'FOLD': 0.9997495892663412},
#  '.1.BET.RAISE.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.09236961238765319,
#   'CHECK_RESPONSE': 0.9020355986642824,
#   'ALL-IN': 0.005594788948064451},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 3.1259397653248356e-05,
#   'FOLD': 0.5663554552922628,
#   'RAISE': 0.43358202591243067,
#   'RAISE-ALL-IN': 3.1259397653248356e-05},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {'BET': 0.3333333333333333,
#   'CHECK_INITIATE': 0.3333333333333333,
#   'ALL-IN': 0.3333333333333333},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.BET': {'CALL': 0.42233578460143495,
#   'FOLD': 0.4992857163304477,
#   'RAISE': 0.06323610319937514,
#   'RAISE-ALL-IN': 0.015142395868742145},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.BET.CALL': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.BET.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE': {'CALL': 0.3333333333333333,
#   'FOLD': 0.3333333333333333,
#   'RAISE-ALL-IN': 0.3333333333333333},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.11972904007857785,
#   'FOLD': 0.8802709599214221},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.5,
#   'FOLD': 0.5},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE': {'BET': 0.23220139484879684,
#   'CHECK_RESPONSE': 0.7476087439928802,
#   'ALL-IN': 0.020189861158322858},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.25,
#   'FOLD': 0.25,
#   'RAISE': 0.25,
#   'RAISE-ALL-IN': 0.25},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.44400608677131986,
#   'FOLD': 0.5270106518498098,
#   'RAISE-ALL-IN': 0.02898326137887033},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.5,
#   'FOLD': 0.5},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.043474892068305494,
#   'FOLD': 0.9565251079316945},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 0.5,
#   'FOLD': 0.5},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.ALL-IN': {'CALL-ALL-IN': 0.030284791737484287,
#   'FOLD': 0.9697152082625158},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL.ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.05629809009253249,
#   'FOLD': 0.349438566901012,
#   'RAISE-ALL-IN': 0.5942633430064554},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {'BET': 0.057715144061938846,
#   'CHECK_INITIATE': 0.9422608240396083,
#   'ALL-IN': 2.4031898452944462e-05},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET': {'CALL': 0.1445517238139185,
#   'FOLD': 0.08965606615223741,
#   'RAISE': 0.1754620768365169,
#   'RAISE-ALL-IN': 0.5903301331973271},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.CALL': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.4118305106697472,
#   'FOLD': 0.5880306933011022,
#   'RAISE-ALL-IN': 0.0001387960291505343},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.2554855948609698,
#   'FOLD': 0.7445144051390302},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.00020819404372580158,
#   'FOLD': 0.9997918059562741},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.18453902975267797,
#   'CHECK_RESPONSE': 0.32237878510806506,
#   'ALL-IN': 0.49308218513925695},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 6.376126927870203e-06,
#   'FOLD': 0.9832746730626089,
#   'RAISE': 0.016712574683535538,
#   'RAISE-ALL-IN': 6.376126927870203e-06},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.3744252058877288,
#   'FOLD': 0.40964681093435334,
#   'RAISE-ALL-IN': 0.2159279831779178},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.00019075836753482608,
#   'FOLD': 0.9998092416324652},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.32389197476687664,
#   'FOLD': 0.6761080252331233},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 1.275225385574041e-05,
#   'FOLD': 0.9999872477461442},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.ALL-IN': {'CALL-ALL-IN': 0.1793121323044749,
#   'FOLD': 0.8206878676955252},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL.ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 3.604784767941664e-05,
#   'FOLD': 0.9999639521523207},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.030284791737484287,
#   'FOLD': 0.9697152082625158},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {'BET': 0.9929698050351143,
#   'CHECK_INITIATE': 0.006988515768014599,
#   'ALL-IN': 4.167919687099793e-05},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET': {'CALL': 0.1508244378518337,
#   'FOLD': 0.6724137465484963,
#   'RAISE': 0.10316089228944886,
#   'RAISE-ALL-IN': 0.07360092331022124},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.CALL': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE': {'CALL': 0.009623896512038077,
#   'FOLD': 0.9637441601752127,
#   'RAISE-ALL-IN': 0.02663194331274917},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.CALL': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.007515449383458603,
#   'FOLD': 0.9924845506165415},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 2.0987142136474144e-05,
#   'FOLD': 0.9999790128578635},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE': {'BET': 0.08588523496207379,
#   'CHECK_RESPONSE': 0.4811819833698013,
#   'ALL-IN': 0.4329327816681249},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET': {'CALL': 0.0014909888685433552,
#   'FOLD': 0.0014909888685433552,
#   'RAISE': 0.99552703339437,
#   'RAISE-ALL-IN': 0.0014909888685433552},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE': {'CALL': 0.060893685219053174,
#   'FOLD': 0.6717164406408945,
#   'RAISE-ALL-IN': 0.2673898741400522},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0007488439884247283,
#   'FOLD': 0.9992511560115753},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.012036224304773602,
#   'FOLD': 0.9879637756952265},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 0.00298197773708671,
#   'FOLD': 0.9970180222629133},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.ALL-IN': {'CALL-ALL-IN': 0.0031012018574151125,
#   'FOLD': 0.9968987981425849},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE.ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 6.251879530649693e-05,
#   'FOLD': 0.9999374812046935},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.BET.RAISE.CALL.ALL-IN': {'CALL-ALL-IN': 0.008392183422096673,
#   'FOLD': 0.9916078165779033},
#  '.1.BET.RAISE.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.CALL.ALL-IN.FOLD': {},
#  '.1.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.008392183422096673,
#   'FOLD': 0.9916078165779033},
#  '.1.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.00012359996058270063,
#   'FOLD': 0.9998764000394172},
#  '.1.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE': {'BET': 0.4426478803522813,
#   'CHECK_RESPONSE': 0.557240100178191,
#   'ALL-IN': 0.00011201946952772746},
#  '.1.CHECK_INITIATE.BET': {'CALL': 0.002217123512085014,
#   'FOLD': 0.9734158405622306,
#   'RAISE': 0.02434059448457231,
#   'RAISE-ALL-IN': 2.6441441111873424e-05},
#  '.1.CHECK_INITIATE.BET.CALL': {'BET': 0.29086273326391554,
#   'CHECK_INITIATE': 0.7051619294777333,
#   'ALL-IN': 0.003975337258351102},
#  '.1.CHECK_INITIATE.BET.CALL.BET': {'CALL': 0.0009975807746618799,
#   'FOLD': 0.667020802516481,
#   'RAISE': 0.33191361500866623,
#   'RAISE-ALL-IN': 6.800170019081038e-05},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL': {'BET': 0.6935458239086915,
#   'CHECK_INITIATE': 0.3018983761626597,
#   'ALL-IN': 0.004555799928648887},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.BET': {'CALL': 0.06337487955699714,
#   'FOLD': 0.22226328398854375,
#   'RAISE': 0.6973201838088728,
#   'RAISE-ALL-IN': 0.017041652645586217},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.BET.CALL': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.BET.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.BET.RAISE': {'CALL': 0.03225441901536794,
#   'FOLD': 0.9243872297844248,
#   'RAISE-ALL-IN': 0.043358351200207264},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.012219388626112914,
#   'FOLD': 0.9877806113738871},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0032844260404981396,
#   'FOLD': 0.9967155739595019},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE': {'BET': 0.7012166712888177,
#   'CHECK_RESPONSE': 0.02272220352744829,
#   'ALL-IN': 0.27606112518373405},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.281144573468346,
#   'FOLD': 0.43306692676345354,
#   'RAISE': 0.09531541165020319,
#   'RAISE-ALL-IN': 0.19047308811799737},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.2118072474413052,
#   'FOLD': 0.22033611948808537,
#   'RAISE-ALL-IN': 0.5678566330706095},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.019790225898295877,
#   'FOLD': 0.9802097741017042},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.016201984677350498,
#   'FOLD': 0.9837980153226494},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 0.00754525411258633,
#   'FOLD': 0.9924547458874137},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.ALL-IN': {'CALL-ALL-IN': 0.03408330529117248,
#   'FOLD': 0.9659166947088276},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL.ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE': {'CALL': 0.01932377256291603,
#   'FOLD': 0.9421962661209987,
#   'RAISE-ALL-IN': 0.03847996131608541},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL': {'BET': 0.4017346972355734,
#   'CHECK_INITIATE': 0.0785871377481755,
#   'ALL-IN': 0.5196781650162511},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.BET': {'CALL': 0.010368980899616726,
#   'FOLD': 0.9669679513213751,
#   'RAISE': 0.008142612042702255,
#   'RAISE-ALL-IN': 0.014520455736305733},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.BET.CALL': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.BET.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.29358366069063224,
#   'FOLD': 0.2002077108272403,
#   'RAISE-ALL-IN': 0.5062086284821274},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0031451471806679962,
#   'FOLD': 0.996854852819332},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.09780974644330104,
#   'FOLD': 0.902190253556699},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.15765407973000814,
#   'CHECK_RESPONSE': 0.7785903516322932,
#   'ALL-IN': 0.06375556863769857},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 0.25,
#   'FOLD': 0.25,
#   'RAISE': 0.25,
#   'RAISE-ALL-IN': 0.25},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.014602836090975993,
#   'FOLD': 0.9785951123017129,
#   'RAISE-ALL-IN': 0.006802051607311045},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.5,
#   'FOLD': 0.5},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.00021658991934101488,
#   'FOLD': 0.999783410080659},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 0.5,
#   'FOLD': 0.5},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.ALL-IN': {'CALL-ALL-IN': 0.0001024388532375131,
#   'FOLD': 0.9998975611467624},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL.ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0001024388532375131,
#   'FOLD': 0.9998975611467624},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.006833699892973333,
#   'FOLD': 0.9931663001070268},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.CHECK_INITIATE': {'BET': 0.1971166142688039,
#   'CHECK_RESPONSE': 0.8028427589130281,
#   'ALL-IN': 4.0626818168011605e-05},
#  '.1.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.0014093703489124019,
#   'FOLD': 0.0014093703489124019,
#   'RAISE': 0.9936272195121767,
#   'RAISE-ALL-IN': 0.0035540397899985047},
#  '.1.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.CALL': {'BET': 0.33333333333333337,
#   'CHECK_INITIATE': 0.33333333333333337,
#   'ALL-IN': 0.33333333333333337},
# ...
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.CALL.ALL-IN': {'CALL-ALL-IN': 0.00042819601470918693,
#   'FOLD': 0.9995718039852908},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.CALL.ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.00042819601470918693,
#   'FOLD': 0.9995718039852908},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 3.129314816487447e-05,
#   'FOLD': 0.9999687068518353},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE': {'BET': 0.7795885386648951,
#   'CHECK_RESPONSE': 0.22039160519118925,
#   'ALL-IN': 1.9856143915610638e-05},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET': {'CALL': 9.909414281583115e-05,
#   'FOLD': 0.99950790071028,
#   'RAISE': 0.00037282046080588265,
#   'RAISE-ALL-IN': 2.0184686098251663e-05},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL': {'BET': 0.8642053201485017,
#   'CHECK_INITIATE': 0.06789733992574913,
#   'ALL-IN': 0.06789733992574913},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.BET': {'CALL': 0.0023316028563958647,
#   'FOLD': 0.9913435484226841,
#   'RAISE': 0.006309366564204979,
#   'RAISE-ALL-IN': 1.54821567150419e-05},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.BET.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.BET.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.BET.RAISE': {'CALL': 0.5151624691304459,
#   'FOLD': 0.4586487929455301,
#   'RAISE-ALL-IN': 0.026188737924024017},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0012269184677648184,
#   'FOLD': 0.9987730815322352},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.03928310688603602,
#   'FOLD': 0.960716893113964},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE': {'BET': 0.5283687492891006,
#   'CHECK_RESPONSE': 0.4643828379162494,
#   'ALL-IN': 0.007248412794650029},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.25,
#   'FOLD': 0.25,
#   'RAISE': 0.25,
#   'RAISE-ALL-IN': 0.25},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.0006118537539642401,
#   'FOLD': 0.9993751232227224,
#   'RAISE-ALL-IN': 1.3023023313314208e-05},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.5,
#   'FOLD': 0.5},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 1.953453496997131e-05,
#   'FOLD': 0.9999804654650299},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 0.5,
#   'FOLD': 0.5},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.ALL-IN': {'CALL-ALL-IN': 1.2735015287433416e-05,
#   'FOLD': 0.9999872649847126},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL.ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE': {'CALL': 0.002363787542423789,
#   'FOLD': 0.9976277224473844,
#   'RAISE-ALL-IN': 8.490010191622274e-06},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL': {'BET': 0.8313464290862865,
#   'CHECK_INITIATE': 0.15033379964682755,
#   'ALL-IN': 0.018319771266885925},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.BET': {'CALL': 0.013023281809825768,
#   'FOLD': 0.9587266296304873,
#   'RAISE': 0.01733016715101757,
#   'RAISE-ALL-IN': 0.010919921408669458},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.BET.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.BET.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.39198317827245766,
#   'FOLD': 0.16556447257916507,
#   'RAISE-ALL-IN': 0.44245234914837733},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.07210727419479038,
#   'FOLD': 0.9278927258052095},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.010853978948051056,
#   'FOLD': 0.9891460210519488},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.015006866982209793,
#   'CHECK_RESPONSE': 0.024877193302735547,
#   'ALL-IN': 0.9601159397150546},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 0.42401997946346826,
#   'FOLD': 0.2809859871221537,
#   'RAISE': 0.2634560437278375,
#   'RAISE-ALL-IN': 0.0315379896865406},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.44414048661070904,
#   'FOLD': 0.39849642277066316,
#   'RAISE-ALL-IN': 0.1573630906186279},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.056956883644839265,
#   'FOLD': 0.9430431163551607},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 0.044473145085746256,
#   'FOLD': 0.9555268549142537},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 0.060022540912544504,
#   'FOLD': 0.9399774590874554},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.ALL-IN': {'CALL-ALL-IN': 0.0017958488314302472,
#   'FOLD': 0.9982041511685698},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL.ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.027070249919519937,
#   'FOLD': 0.97292975008048},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 1.2735015287433416e-05,
#   'FOLD': 0.9999872649847126},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE': {'BET': 0.5001270049166839,
#   'CHECK_INITIATE': 0.4907456805501241,
#   'ALL-IN': 0.009127314533191948},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.BET': {'CALL': 0.0008772460929859801,
#   'FOLD': 0.9864147957205948,
#   'RAISE': 0.008184127933708898,
#   'RAISE-ALL-IN': 0.004523830252710348},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.BET.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.BET.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE': {'CALL': 0.0001475543782410635,
#   'FOLD': 0.9998345082348331,
#   'RAISE-ALL-IN': 1.793738692578184e-05},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.00389896963035634,
#   'FOLD': 0.9961010303696437},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 2.6906080388672762e-05,
#   'FOLD': 0.9999730939196113},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE': {'BET': 0.9772324744846989,
#   'CHECK_RESPONSE': 0.0015133092788529973,
#   'ALL-IN': 0.021254216236448135},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET': {'CALL': 7.301360204670279e-05,
#   'FOLD': 0.9517922691079649,
#   'RAISE': 0.01814963169191754,
#   'RAISE-ALL-IN': 0.029985085598070872},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE': {'CALL': 0.009752127734932501,
#   'FOLD': 0.9901629898333023,
#   'RAISE-ALL-IN': 8.488243176527785e-05},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.0003776995326073612,
#   'FOLD': 0.9996223004673928},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE-ALL-IN': {'CALL-ALL-IN': 2.17194000737558e-05,
#   'FOLD': 0.9999782805999262},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE-ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE-ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 2.7420429628132022e-05,
#   'FOLD': 0.9999725795703718},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.ALL-IN': {'CALL-ALL-IN': 4.504741434771409e-05,
#   'FOLD': 0.9999549525856523},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE.ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 4.0369372196503326e-05,
#   'FOLD': 0.9999596306278035},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.ALL-IN': {'CALL-ALL-IN': 2.9784215873415838e-05,
#   'FOLD': 0.9999702157841265},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.ALL-IN.FOLD': {},
#  '.1.CHECK_INITIATE.ALL-IN': {'CALL-ALL-IN': 1.91301949776641e-05,
#   'FOLD': 0.9999808698050224},
#  '.1.CHECK_INITIATE.ALL-IN.CALL-ALL-IN': {},
#  '.1.CHECK_INITIATE.ALL-IN.FOLD': {},
#  '.1.ALL-IN': {'CALL-ALL-IN': 0.00014937263493328023,
#   'FOLD': 0.9998506273650667},
#  '.1.ALL-IN.CALL-ALL-IN': {},
#  '.1.ALL-IN.FOLD': {},
#  '.2.BET': {'CALL': 0.1819830781399914,
#   'FOLD': 0.6729836763941156,
#   'RAISE': 0.1450085906335459,
#   'RAISE-ALL-IN': 2.465483234714004e-05},
#  '.2.BET.CALL.BET': {'CALL': 0.07552936827300769,
#   'FOLD': 0.7281891569474531,
#   'RAISE': 0.19572729225579585,
#   'RAISE-ALL-IN': 0.0005541825237433637},
#  '.2.BET.CALL.BET.CALL.BET': {'CALL': 0.003129894610123988,
#   'FOLD': 0.9914290254792898,
#   'RAISE': 0.0037470995840644867,
#   'RAISE-ALL-IN': 0.0016939803265215035},
#  '.2.BET.CALL.BET.CALL.BET.RAISE.CALL': {},
#  '.2.BET.CALL.BET.CALL.BET.RAISE.FOLD': {},
#  '.2.BET.CALL.BET.CALL.BET.RAISE.RAISE-ALL-IN': {'CALL-ALL-IN': 0.014959255548734863,
#   'FOLD': 0.9850407444512651},
#  ...}

# %%
with open('output/poker_bot_strategy.pkl', 'wb') as f:
    pickle.dump(chance_sampling_cfr.nash_equilibrium, file = f)

# %% [markdown]
# # Get some stats

# %%
def get_aggression(bots):
    results = []
    
    for b in bots:
        g = b.root.max_hand_strength
        d = b.root.max_turns
        
        for i in range(1,g+1):
            p1 = b.nash_equilibrium[f'.{i}.']['BET']
            p2 = b.nash_equilibrium[f'.{i}.CHECK_INITIATE']['BET']
            p3 = b.nash_equilibrium[f'.{i}.BET']['RAISE']
            p4 = b.nash_equilibrium[f'.{i}.CHECK_INITIATE.BET']['RAISE']
            results.append([g,d,i,p1,"Initial bet"])
            results.append([g,d,i,p2,"Bet after check"])
            results.append([g,d,i,p3,"Raise after bet"])
            results.append([g,d,i,p4,"Check-raise"])
            
    return results

# %%
s['.10.ALL-IN']
# Out:
# {'CALL-ALL-IN': 0.9998998196754157, 'FOLD': 0.00010018032458425165}

# %%
pd.DataFrame(get_aggression([chance_sampling_cfr]))
# Out:
#      0  1   2         3                4
# 0   10  3   1  0.134026      Initial bet
# 1   10  3   1  0.442648  Bet after check
# 2   10  3   1  0.006180  Raise after bet
# 3   10  3   1  0.024341      Check-raise
# 4   10  3   2  0.546088      Initial bet
# 5   10  3   2  0.419241  Bet after check
# 6   10  3   2  0.145009  Raise after bet
# 7   10  3   2  0.046206      Check-raise
# 8   10  3   3  0.396340      Initial bet
# 9   10  3   3  0.576850  Bet after check
# 10  10  3   3  0.090426  Raise after bet
# 11  10  3   3  0.055217      Check-raise
# 12  10  3   4  0.012060      Initial bet
# 13  10  3   4  0.056841  Bet after check
# 14  10  3   4  0.075162  Raise after bet
# 15  10  3   4  0.008627      Check-raise
# 16  10  3   5  0.043311      Initial bet
# 17  10  3   5  0.011902  Bet after check
# 18  10  3   5  0.127321  Raise after bet
# 19  10  3   5  0.028919      Check-raise
# 20  10  3   6  0.019708      Initial bet
# 21  10  3   6  0.067055  Bet after check
# 22  10  3   6  0.018571  Raise after bet
# 23  10  3   6  0.013047      Check-raise
# 24  10  3   7  0.017322      Initial bet
# 25  10  3   7  0.003115  Bet after check
# 26  10  3   7  0.085230  Raise after bet
# 27  10  3   7  0.041810      Check-raise
# 28  10  3   8  0.119170      Initial bet
# 29  10  3   8  0.225484  Bet after check
# 30  10  3   8  0.068353  Raise after bet
# 31  10  3   8  0.139106      Check-raise
# 32  10  3   9  0.813835      Initial bet
# 33  10  3   9  0.840907  Bet after check
# 34  10  3   9  0.331872  Raise after bet
# 35  10  3   9  0.279412      Check-raise
# 36  10  3  10  0.324528      Initial bet
# 37  10  3  10  0.659523  Bet after check
# 38  10  3  10  0.259663  Raise after bet
# 39  10  3  10  0.156343      Check-raise
