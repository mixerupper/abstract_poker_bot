# %%
import sys
sys.path.append("..")
import pickle

# %%
from games.abstract_poker_additional import AbstractPokerRootChanceGameState
from games.algorithms import ChanceSamplingCFR, VanillaCFR
from common.constants import card_dealing, results_map
import numpy as np
import pandas as pd

# %%
# Hyperparameters
_MAX_HAND_STRENGTH = 5
_MAX_TURNS = 2
_NUM_TRAIN_ITERS = 50_000
_ANTE_SIZE = 1

# %%
# card_dealing(_MAX_HAND_STRENGTH)

# %% [markdown]
# # Train

# %%
root = AbstractPokerRootChanceGameState(max_hand_strength = _MAX_HAND_STRENGTH,
                                    max_turns = _MAX_TURNS,
                                    ante = _ANTE_SIZE,
                                    report = False)
chance_sampling_cfr = ChanceSamplingCFR(root)
chance_sampling_cfr.run(iterations = _NUM_TRAIN_ITERS)
chance_sampling_cfr.compute_nash_equilibrium()

    # vanilla cfr
#     vanilla_cfr_g3 = VanillaCFR(root)
#     vanilla_cfr_g3.run(iterations = _NUM_TRAIN_ITERS)
#     vanilla_cfr_g3.compute_nash_equilibrium()

# %%
chance_sampling_cfr.nash_equilibrium
# Out:
# {'.': {'1.1': 0.04,
#   '1.2': 0.04,
#   '1.3': 0.04,
#   '1.4': 0.04,
#   '1.5': 0.04,
#   '2.1': 0.04,
#   '2.2': 0.04,
#   '2.3': 0.04,
#   '2.4': 0.04,
#   '2.5': 0.04,
#   '3.1': 0.04,
#   '3.2': 0.04,
#   '3.3': 0.04,
#   '3.4': 0.04,
#   '3.5': 0.04,
#   '4.1': 0.04,
#   '4.2': 0.04,
#   '4.3': 0.04,
#   '4.4': 0.04,
#   '4.5': 0.04,
#   '5.1': 0.04,
#   '5.2': 0.04,
#   '5.3': 0.04,
#   '5.4': 0.04,
#   '5.5': 0.04},
#  '.1.': {'BET': 0.45790427086484325, 'CHECK_INITIATE': 0.5420957291351569},
#  '.1.BET': {'CALL': 0.18217361677939636,
#   'FOLD': 0.799208223743454,
#   'RAISE': 0.018618159477149464},
#  '.1.BET.CALL': {'BET': 0.30747173684790097,
#   'CHECK_INITIATE': 0.692528263152099},
#  '.1.BET.CALL.BET': {'CALL': 6.053784472274723e-05,
#   'FOLD': 0.9998789243105546,
#   'RAISE': 6.053784472274723e-05},
#  '.1.BET.CALL.BET.CALL': {},
#  '.1.BET.CALL.BET.FOLD': {},
#  '.1.BET.CALL.BET.RAISE': {'CALL': 8.835893879992628e-05,
#   'FOLD': 0.9999116410612001},
#  '.1.BET.CALL.BET.RAISE.CALL': {},
#  '.1.BET.CALL.BET.RAISE.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE': {'BET': 0.9999091932329158,
#   'CHECK_RESPONSE': 9.080676708412084e-05},
#  '.1.BET.CALL.CHECK_INITIATE.BET': {'CALL': 2.615332622449602e-05,
#   'FOLD': 0.9982596184646971,
#   'RAISE': 0.0017142282090783145},
#  '.1.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.07641014359177267,
#   'FOLD': 0.9235898564082273},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.BET.FOLD': {},
#  '.1.BET.RAISE': {'CALL': 0.0012898413228028221, 'FOLD': 0.9987101586771973},
#  '.1.BET.RAISE.CALL': {'BET': 0.9789370398524565,
#   'CHECK_INITIATE': 0.02106296014754355},
#  '.1.BET.RAISE.CALL.BET': {'CALL': 0.0005923463132168238,
#   'FOLD': 0.9988153073735663,
#   'RAISE': 0.0005923463132168238},
#  '.1.BET.RAISE.CALL.BET.CALL': {},
#  '.1.BET.RAISE.CALL.BET.FOLD': {},
#  '.1.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.010758077021336385,
#   'FOLD': 0.9892419229786636},
#  '.1.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.1.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.0861066740253853,
#   'CHECK_RESPONSE': 0.9138933259746146},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 0.3333333333333333,
#   'FOLD': 0.3333333333333333,
#   'RAISE': 0.3333333333333333},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.005159411159948467,
#   'FOLD': 0.9948405888400516},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE': {'BET': 0.6416478080106653,
#   'CHECK_RESPONSE': 0.35835219198933466},
#  '.1.CHECK_INITIATE.BET': {'CALL': 0.0021095102401462707,
#   'FOLD': 0.9962095918067515,
#   'RAISE': 0.0016808979531022599},
#  '.1.CHECK_INITIATE.BET.CALL': {'BET': 0.992747604096547,
#   'CHECK_INITIATE': 0.00725239590345287},
#  '.1.CHECK_INITIATE.BET.CALL.BET': {'CALL': 5.1562857322138525e-05,
#   'FOLD': 0.9797747678659615,
#   'RAISE': 0.020173669276716332},
#  '.1.CHECK_INITIATE.BET.CALL.BET.CALL': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE': {'CALL': 0.0036526886962638073,
#   'FOLD': 0.9963473113037362},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.BET.CALL.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.CHECK_INITIATE': {'BET': 0.35669216385694347,
#   'CHECK_RESPONSE': 0.6433078361430565},
#  '.1.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.3333333333333333,
#   'FOLD': 0.3333333333333333,
#   'RAISE': 0.3333333333333333},
#  '.1.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.00010841881855053634,
#   'FOLD': 0.9998915811814495},
#  '.1.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.CHECK_INITIATE.BET.FOLD': {},
#  '.1.CHECK_INITIATE.BET.RAISE': {'CALL': 0.15057478961093337,
#   'FOLD': 0.8494252103890666},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL': {'BET': 0.7156809721512633,
#   'CHECK_INITIATE': 0.28431902784873675},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL.BET': {'CALL': 0.000171220087557056,
#   'FOLD': 0.6836362806347721,
#   'RAISE': 0.31619249927767085},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL.BET.CALL': {},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL.BET.FOLD': {},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.08266385971902379,
#   'FOLD': 0.9173361402809762},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.9997431698686644,
#   'CHECK_RESPONSE': 0.000256830131335584},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 0.13871964399315867,
#   'FOLD': 0.7225607120136827,
#   'RAISE': 0.13871964399315867},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.0001284480549986271,
#   'FOLD': 0.9998715519450013},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.1.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE': {'BET': 0.6775232684948845,
#   'CHECK_INITIATE': 0.32247673150511547},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET': {'CALL': 0.0001421014437502786,
#   'FOLD': 0.9988012743556355,
#   'RAISE': 0.0010566242006141344},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE': {'CALL': 0.0005693693748822984,
#   'FOLD': 0.9994306306251177},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE': {'BET': 0.9324160433735552,
#   'CHECK_RESPONSE': 0.06758395662644474},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET': {'CALL': 0.00014232657983590972,
#   'FOLD': 0.9989021460634091,
#   'RAISE': 0.0009555273567549147},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE': {'CALL': 0.0005741659428604439,
#   'FOLD': 0.9994258340571395},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.1.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.2.BET': {'CALL': 0.26606637531680993,
#   'FOLD': 0.7265095132208951,
#   'RAISE': 0.007424111462295036},
#  '.2.BET.CALL.BET': {'CALL': 0.338412532512932,
#   'FOLD': 0.6609205156837327,
#   'RAISE': 0.0006669518033354071},
#  '.2.BET.CALL.BET.RAISE.CALL': {},
#  '.2.BET.CALL.BET.RAISE.FOLD': {},
#  '.2.BET.CALL.CHECK_INITIATE': {'BET': 0.496983946124115,
#   'CHECK_RESPONSE': 0.5030160538758851},
#  '.2.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.2.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.2.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.006341836761324525,
#   'FOLD': 0.9936581632386754},
#  '.2.BET.RAISE.CALL.BET': {'CALL': 0.005629626473384538,
#   'FOLD': 0.9426097690662919,
#   'RAISE': 0.05176060446032351},
#  '.2.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.2.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.2.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.7554682380291163,
#   'CHECK_RESPONSE': 0.2445317619708836},
#  '.2.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.2.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.2.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.014932409589604895,
#   'FOLD': 0.9850675904103952},
#  '.2.BET.RAISE.FOLD': {},
#  '.2.CHECK_INITIATE': {'BET': 0.03957553979608166,
#   'CHECK_RESPONSE': 0.9604244602039183},
#  '.2.CHECK_INITIATE.BET.CALL.BET': {'CALL': 0.036306852324421844,
#   'FOLD': 0.8674821660848447,
#   'RAISE': 0.09621098159073331},
#  '.2.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL': {},
#  '.2.CHECK_INITIATE.BET.CALL.BET.RAISE.FOLD': {},
#  '.2.CHECK_INITIATE.BET.CALL.CHECK_INITIATE': {'BET': 0.08600190300518509,
#   'CHECK_RESPONSE': 0.9139980969948148},
#  '.2.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.2.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.2.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.9668146183759935,
#   'FOLD': 0.03318538162400648},
#  '.2.CHECK_INITIATE.BET.FOLD': {},
#  '.2.CHECK_INITIATE.BET.RAISE': {'CALL': 0.6798198970751564,
#   'FOLD': 0.32018010292484367},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL.BET': {'CALL': 0.1481871413658084,
#   'FOLD': 0.8269396812909652,
#   'RAISE': 0.02487317734322633},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.7820852866980548,
#   'CHECK_RESPONSE': 0.2179147133019453},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.0006992034659165289,
#   'FOLD': 0.9993007965340835},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE.BET': {'CALL': 0.2802385067225824,
#   'FOLD': 0.7192170336412005,
#   'RAISE': 0.0005444596362171719},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.CALL': {},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.FOLD': {},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE': {'BET': 0.003184143914368751,
#   'CHECK_RESPONSE': 0.9968158560856313},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL': {},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.FOLD': {},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE': {'CALL': 0.40197577698787257,
#   'FOLD': 0.5980242230121274},
#  '.3.BET': {'CALL': 0.8517753737088186,
#   'FOLD': 0.145278943860931,
#   'RAISE': 0.0029456824302504176},
#  '.3.BET.CALL.BET': {'CALL': 0.7217228462490083,
#   'FOLD': 0.2781230710863276,
#   'RAISE': 0.00015408266466409348},
#  '.3.BET.CALL.BET.RAISE.CALL': {},
#  '.3.BET.CALL.BET.RAISE.FOLD': {},
#  '.3.BET.CALL.CHECK_INITIATE': {'BET': 0.0013736186640831588,
#   'CHECK_RESPONSE': 0.9986263813359167},
#  '.3.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.3.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.3.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.9843593662084492,
#   'FOLD': 0.0156406337915507},
#  '.3.BET.RAISE.CALL.BET': {'CALL': 0.310818746309503,
#   'FOLD': 0.5825611631551418,
#   'RAISE': 0.10662009053535512},
#  '.3.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.3.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.3.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.46416014311647846,
#   'CHECK_RESPONSE': 0.5358398568835214},
#  '.3.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.3.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.3.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.7506106274312767,
#   'FOLD': 0.24938937256872334},
#  '.3.BET.RAISE.FOLD': {},
#  '.3.CHECK_INITIATE': {'BET': 0.0028394914274284663,
#   'CHECK_RESPONSE': 0.9971605085725714},
#  '.3.CHECK_INITIATE.BET.CALL.BET': {'CALL': 0.24397565386546213,
#   'FOLD': 0.392956767817996,
#   'RAISE': 0.36306757831654185},
#  '.3.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL': {},
#  '.3.CHECK_INITIATE.BET.CALL.BET.RAISE.FOLD': {},
#  '.3.CHECK_INITIATE.BET.CALL.CHECK_INITIATE': {'BET': 0.5778674967841961,
#   'CHECK_RESPONSE': 0.422132503215804},
#  '.3.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.3.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.3.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.8694838416830475,
#   'FOLD': 0.13051615831695243},
#  '.3.CHECK_INITIATE.BET.FOLD': {},
#  '.3.CHECK_INITIATE.BET.RAISE': {'CALL': 0.367306047035036,
#   'FOLD': 0.632693952964964},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL.BET': {'CALL': 0.8166670465599004,
#   'FOLD': 0.17528575699831517,
#   'RAISE': 0.008047196441784343},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.9879292053373235,
#   'CHECK_RESPONSE': 0.012070794662676517},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.006109139499806063,
#   'FOLD': 0.9938908605001939},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE.BET': {'CALL': 0.9974778636035035,
#   'FOLD': 0.0023857635509026316,
#   'RAISE': 0.0001363728455938573},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.CALL': {},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.FOLD': {},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE': {'BET': 0.2215810827204732,
#   'CHECK_RESPONSE': 0.7784189172795267},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL': {},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.FOLD': {},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE': {'CALL': 0.868448979695576,
#   'FOLD': 0.1315510203044239},
#  '.4.BET': {'CALL': 0.9841885672228599,
#   'FOLD': 0.009850614044724567,
#   'RAISE': 0.005960818732415458},
#  '.4.BET.CALL.BET': {'CALL': 0.983434503973537,
#   'FOLD': 0.015044637135408734,
#   'RAISE': 0.0015208588910542772},
#  '.4.BET.CALL.BET.RAISE.CALL': {},
#  '.4.BET.CALL.BET.RAISE.FOLD': {},
#  '.4.BET.CALL.CHECK_INITIATE': {'BET': 0.18684646763193544,
#   'CHECK_RESPONSE': 0.8131535323680646},
#  '.4.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.4.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.4.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.9999550744372908,
#   'FOLD': 4.49255627092261e-05},
#  '.4.BET.RAISE.CALL.BET': {'CALL': 0.5450254573335135,
#   'FOLD': 0.0018479471839914653,
#   'RAISE': 0.453126595482495},
#  '.4.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.4.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.4.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.19742006238268014,
#   'CHECK_RESPONSE': 0.8025799376173198},
#  '.4.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.4.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.4.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.9929796375744879,
#   'FOLD': 0.007020362425511979},
#  '.4.BET.RAISE.FOLD': {},
#  '.4.CHECK_INITIATE': {'BET': 0.20797506384760134,
#   'CHECK_RESPONSE': 0.7920249361523986},
#  '.4.CHECK_INITIATE.BET.CALL.BET': {'CALL': 0.9493593987887134,
#   'FOLD': 0.0020540658039113397,
#   'RAISE': 0.048586535407375196},
#  '.4.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL': {},
#  '.4.CHECK_INITIATE.BET.CALL.BET.RAISE.FOLD': {},
#  '.4.CHECK_INITIATE.BET.CALL.CHECK_INITIATE': {'BET': 0.9998808300597635,
#   'CHECK_RESPONSE': 0.00011916994023656342},
#  '.4.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.4.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.4.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.6120135041657081,
#   'FOLD': 0.387986495834292},
#  '.4.CHECK_INITIATE.BET.FOLD': {},
#  '.4.CHECK_INITIATE.BET.RAISE': {'CALL': 0.6843750902351263,
#   'FOLD': 0.3156249097648735},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL.BET': {'CALL': 0.7186257197383078,
#   'FOLD': 0.2242826271595894,
#   'RAISE': 0.05709165310210279},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.09174712096120598,
#   'CHECK_RESPONSE': 0.908252879038794},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.898800875174468,
#   'FOLD': 0.10119912482553202},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE.BET': {'CALL': 0.9572006229053932,
#   'FOLD': 2.0861612472131553e-05,
#   'RAISE': 0.042778515482134606},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.CALL': {},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.FOLD': {},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE': {'BET': 0.9998250243768525,
#   'CHECK_RESPONSE': 0.00017497562314748631},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL': {},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.FOLD': {},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE': {'CALL': 0.8696612039075953,
#   'FOLD': 0.13033879609240479},
#  '.5.BET': {'CALL': 0.9391003846066758,
#   'FOLD': 0.00013411117816670024,
#   'RAISE': 0.060765504215157515},
#  '.5.BET.CALL.BET': {'CALL': 7.967726822807284e-05,
#   'FOLD': 4.7602712966931705e-05,
#   'RAISE': 0.999872720018805},
#  '.5.BET.CALL.BET.RAISE.CALL': {},
#  '.5.BET.CALL.BET.RAISE.FOLD': {},
#  '.5.BET.CALL.CHECK_INITIATE': {'BET': 0.9998843934622571,
#   'CHECK_RESPONSE': 0.00011560653774280455},
#  '.5.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.5.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.5.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.9999422400311028,
#   'FOLD': 5.775996889725765e-05},
#  '.5.BET.RAISE.CALL.BET': {'CALL': 0.003959682480637363,
#   'FOLD': 0.0007356760489846427,
#   'RAISE': 0.9953046414703781},
#  '.5.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.5.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.5.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.9891142483833697,
#   'CHECK_RESPONSE': 0.010885751616630295},
#  '.5.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.5.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.5.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.9960213636288947,
#   'FOLD': 0.003978636371105265},
#  '.5.BET.RAISE.FOLD': {},
#  '.5.CHECK_INITIATE': {'BET': 0.9684435781114857,
#   'CHECK_RESPONSE': 0.0315564218885143},
#  '.5.CHECK_INITIATE.BET.CALL.BET': {'CALL': 0.000294009112817239,
#   'FOLD': 1.7310143460838456e-05,
#   'RAISE': 0.999688680743722},
#  '.5.CHECK_INITIATE.BET.CALL.BET.RAISE.CALL': {},
#  '.5.CHECK_INITIATE.BET.CALL.BET.RAISE.FOLD': {},
#  '.5.CHECK_INITIATE.BET.CALL.CHECK_INITIATE': {'BET': 0.9996109028940967,
#   'CHECK_RESPONSE': 0.0003890971059032516},
#  '.5.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.5.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.5.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.9998630923215855,
#   'FOLD': 0.00013690767841451347},
#  '.5.CHECK_INITIATE.BET.FOLD': {},
#  '.5.CHECK_INITIATE.BET.RAISE': {'CALL': 0.9999740347848087,
#   'FOLD': 2.5965215191257686e-05},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL.BET': {'CALL': 0.00012854762807907184,
#   'FOLD': 8.65529646705454e-06,
#   'RAISE': 0.9998627970754539},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.CALL': {},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE.FOLD': {},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE': {'BET': 0.9998550394394001,
#   'CHECK_RESPONSE': 0.00014496056059992184},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.CALL': {},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.FOLD': {},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE': {'CALL': 0.9999935075865058,
#   'FOLD': 6.4924134941906696e-06},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE.BET': {'CALL': 0.002353358191444767,
#   'FOLD': 0.000531235680967339,
#   'RAISE': 0.9971154061275879},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.CALL': {},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE.FOLD': {},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE': {'BET': 0.997609439435647,
#   'CHECK_RESPONSE': 0.0023905605643530256},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.CALL': {},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.FOLD': {},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE': {'CALL': 0.9988018554807855,
#   'FOLD': 0.0011981445192145428},
#  '.2.': {'BET': 0.0294396740930182, 'CHECK_INITIATE': 0.9705603259069817},
#  '.2.BET.CALL': {'BET': 0.6929127652969049,
#   'CHECK_INITIATE': 0.3070872347030949},
#  '.2.BET.CALL.BET.CALL': {},
#  '.2.BET.CALL.BET.FOLD': {},
#  '.2.BET.CALL.BET.RAISE': {'CALL': 0.000614738514777194,
#   'FOLD': 0.9993852614852228},
#  '.2.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.0009247321630949901,
#   'FOLD': 0.9563434881729469,
#   'RAISE': 0.042731779663958164},
#  '.2.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.2.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.2.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.2.BET.FOLD': {},
#  '.2.BET.RAISE': {'CALL': 0.07362034834238648, 'FOLD': 0.9263796516576135},
#  '.2.BET.RAISE.CALL': {'BET': 0.006596453203399195,
#   'CHECK_INITIATE': 0.9934035467966007},
#  '.2.BET.RAISE.CALL.BET.CALL': {},
#  '.2.BET.RAISE.CALL.BET.FOLD': {},
#  '.2.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.43856163398570225,
#   'FOLD': 0.5614383660142976},
#  '.2.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 0.0019414408204479006,
#   'FOLD': 0.7053369901163775,
#   'RAISE': 0.2927215690631746},
#  '.2.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.2.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.2.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.2.CHECK_INITIATE.BET': {'CALL': 0.32713717271166476,
#   'FOLD': 0.646663537616259,
#   'RAISE': 0.02619928967207622},
#  '.2.CHECK_INITIATE.BET.CALL': {'BET': 0.0005216550476907939,
#   'CHECK_INITIATE': 0.9994783449523091},
#  '.2.CHECK_INITIATE.BET.CALL.BET.CALL': {},
#  '.2.CHECK_INITIATE.BET.CALL.BET.FOLD': {},
#  '.2.CHECK_INITIATE.BET.CALL.BET.RAISE': {'CALL': 0.0757122476500001,
#   'FOLD': 0.9242877523499999},
#  '.2.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.7001999376693562,
#   'FOLD': 0.279501669345919,
#   'RAISE': 0.02029839298472464},
#  '.2.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.2.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.2.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL': {'BET': 0.3425641860668477,
#   'CHECK_INITIATE': 0.6574358139331523},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL.BET.CALL': {},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL.BET.FOLD': {},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.007198101725303452,
#   'FOLD': 0.9928018982746966},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 0.16468406420845083,
#   'FOLD': 0.8314440763765752,
#   'RAISE': 0.0038718594149740326},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.2.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.2.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE': {'BET': 0.0009814551427352422,
#   'CHECK_INITIATE': 0.9990185448572647},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE.BET.CALL': {},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE.BET.FOLD': {},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE': {'CALL': 0.013164640206442648,
#   'FOLD': 0.9868353597935573},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET': {'CALL': 0.24834328390961022,
#   'FOLD': 0.7350997156682111,
#   'RAISE': 0.016557000422178628},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.2.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.3.': {'BET': 0.014646271709463313, 'CHECK_INITIATE': 0.9853537282905367},
#  '.3.BET.CALL': {'BET': 0.17134780824532608,
#   'CHECK_INITIATE': 0.828652191754674},
#  '.3.BET.CALL.BET.CALL': {},
#  '.3.BET.CALL.BET.FOLD': {},
#  '.3.BET.CALL.BET.RAISE': {'CALL': 0.9950206333766207,
#   'FOLD': 0.004979366623379249},
#  '.3.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.9986271625725799,
#   'FOLD': 0.0006864187137101134,
#   'RAISE': 0.0006864187137101134},
#  '.3.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.3.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.3.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.3.BET.FOLD': {},
#  '.3.BET.RAISE': {'CALL': 0.99341318146598, 'FOLD': 0.00658681853402009},
#  '.3.BET.RAISE.CALL': {'BET': 0.12091161208388812,
#   'CHECK_INITIATE': 0.879088387916112},
#  '.3.BET.RAISE.CALL.BET.CALL': {},
#  '.3.BET.RAISE.CALL.BET.FOLD': {},
#  '.3.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.9100861504770446,
#   'FOLD': 0.08991384952295552},
#  '.3.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 0.003880087641393523,
#   'FOLD': 0.9631674160317334,
#   'RAISE': 0.032952496326873054},
#  '.3.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.3.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.3.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.3.CHECK_INITIATE.BET': {'CALL': 0.7870116591882453,
#   'FOLD': 0.21101999172080146,
#   'RAISE': 0.001968349090953219},
#  '.3.CHECK_INITIATE.BET.CALL': {'BET': 0.002311224383158431,
#   'CHECK_INITIATE': 0.9976887756168415},
#  '.3.CHECK_INITIATE.BET.CALL.BET.CALL': {},
#  '.3.CHECK_INITIATE.BET.CALL.BET.FOLD': {},
#  '.3.CHECK_INITIATE.BET.CALL.BET.RAISE': {'CALL': 0.6983166756762464,
#   'FOLD': 0.3016833243237535},
#  '.3.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.5451541209789159,
#   'FOLD': 0.4479833051656296,
#   'RAISE': 0.006862573855454514},
#  '.3.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.3.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.3.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL': {'BET': 0.06908364307303776,
#   'CHECK_INITIATE': 0.9309163569269622},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL.BET.CALL': {},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL.BET.FOLD': {},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.9689122729880812,
#   'FOLD': 0.03108772701191875},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 0.025419117796692287,
#   'FOLD': 0.9708006428531974,
#   'RAISE': 0.003780239350110399},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.3.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.3.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE': {'BET': 0.08337551980696935,
#   'CHECK_INITIATE': 0.9166244801930307},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE.BET.CALL': {},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE.BET.FOLD': {},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE': {'CALL': 0.1847136949754591,
#   'FOLD': 0.815286305024541},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET': {'CALL': 0.9703465350663827,
#   'FOLD': 9.22369363123076e-06,
#   'RAISE': 0.029644241239985936},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.3.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.4.': {'BET': 0.026470985615775326, 'CHECK_INITIATE': 0.9735290143842247},
#  '.4.BET.CALL': {'BET': 0.9371537867263215,
#   'CHECK_INITIATE': 0.06284621327367837},
#  '.4.BET.CALL.BET.CALL': {},
#  '.4.BET.CALL.BET.FOLD': {},
#  '.4.BET.CALL.BET.RAISE': {'CALL': 0.15308999672359386,
#   'FOLD': 0.8469100032764061},
#  '.4.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.004957653724385012,
#   'FOLD': 0.004957653724385012,
#   'RAISE': 0.9900846925512299},
#  '.4.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.4.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.4.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.4.BET.FOLD': {},
#  '.4.BET.RAISE': {'CALL': 0.9990652907101008, 'FOLD': 0.0009347092898992388},
#  '.4.BET.RAISE.CALL': {'BET': 0.012088715684413666,
#   'CHECK_INITIATE': 0.9879112843155864},
#  '.4.BET.RAISE.CALL.BET.CALL': {},
#  '.4.BET.RAISE.CALL.BET.FOLD': {},
#  '.4.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.98065171244857,
#   'FOLD': 0.019348287551430005},
#  '.4.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 0.9518824694427296,
#   'FOLD': 0.00015783869861118696,
#   'RAISE': 0.047959691858659254},
#  '.4.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.4.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.4.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.4.CHECK_INITIATE.BET': {'CALL': 0.998844899913771,
#   'FOLD': 1.6943632086476313e-05,
#   'RAISE': 0.001138156454142607},
#  '.4.CHECK_INITIATE.BET.CALL': {'BET': 0.0020966077883200545,
#   'CHECK_INITIATE': 0.99790339221168},
#  '.4.CHECK_INITIATE.BET.CALL.BET.CALL': {},
#  '.4.CHECK_INITIATE.BET.CALL.BET.FOLD': {},
#  '.4.CHECK_INITIATE.BET.CALL.BET.RAISE': {'CALL': 0.9979773009519054,
#   'FOLD': 0.0020226990480945607},
#  '.4.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.9999943337112447,
#   'FOLD': 2.833144377676083e-06,
#   'RAISE': 2.833144377676083e-06},
#  '.4.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.4.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.4.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL': {'BET': 0.9925565452689716,
#   'CHECK_INITIATE': 0.007443454731028277},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL.BET.CALL': {},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL.BET.FOLD': {},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.9962503623765782,
#   'FOLD': 0.00374963762342184},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 0.3333333333333333,
#   'FOLD': 0.3333333333333333,
#   'RAISE': 0.3333333333333333},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.4.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.4.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE': {'BET': 0.991468112626726,
#   'CHECK_INITIATE': 0.00853188737327406},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE.BET.CALL': {},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE.BET.FOLD': {},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE': {'CALL': 0.9999871829220698,
#   'FOLD': 1.2817077930212286e-05},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET': {'CALL': 0.0009929591979584641,
#   'FOLD': 0.0009929591979584641,
#   'RAISE': 0.998014081604083},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.4.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.5.': {'BET': 0.809063930741586, 'CHECK_INITIATE': 0.1909360692584141},
#  '.5.BET.CALL': {'BET': 0.9882592025166604,
#   'CHECK_INITIATE': 0.011740797483339655},
#  '.5.BET.CALL.BET.CALL': {},
#  '.5.BET.CALL.BET.FOLD': {},
#  '.5.BET.CALL.BET.RAISE': {'CALL': 0.9999841718101038,
#   'FOLD': 1.5828189896198787e-05},
#  '.5.BET.CALL.CHECK_INITIATE.BET': {'CALL': 0.0008882051011325467,
#   'FOLD': 0.0008882051011325467,
#   'RAISE': 0.9982235897977348},
#  '.5.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.5.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.5.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.5.BET.FOLD': {},
#  '.5.BET.RAISE': {'CALL': 0.9999687152913518, 'FOLD': 3.128470864819934e-05},
#  '.5.BET.RAISE.CALL': {'BET': 0.06468396732278939,
#   'CHECK_INITIATE': 0.9353160326772105},
#  '.5.BET.RAISE.CALL.BET.CALL': {},
#  '.5.BET.RAISE.CALL.BET.FOLD': {},
#  '.5.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.9998790825272988,
#   'FOLD': 0.00012091747270112306},
#  '.5.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 5.574887046870494e-06,
#   'FOLD': 5.574887046870494e-06,
#   'RAISE': 0.9999888502259063},
#  '.5.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.5.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.5.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.5.CHECK_INITIATE.BET': {'CALL': 0.5220203678583712,
#   'FOLD': 8.837628025382326e-05,
#   'RAISE': 0.47789125586137493},
#  '.5.CHECK_INITIATE.BET.CALL': {'BET': 0.10817220987007149,
#   'CHECK_INITIATE': 0.8918277901299285},
#  '.5.CHECK_INITIATE.BET.CALL.BET.CALL': {},
#  '.5.CHECK_INITIATE.BET.CALL.BET.FOLD': {},
#  '.5.CHECK_INITIATE.BET.CALL.BET.RAISE': {'CALL': 0.9996087335801976,
#   'FOLD': 0.0003912664198022638},
#  '.5.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET': {'CALL': 3.163850969613454e-05,
#   'FOLD': 3.163850969613454e-05,
#   'RAISE': 0.9999367229806078},
#  '.5.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.5.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.5.CHECK_INITIATE.BET.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL': {'BET': 0.8347847116183198,
#   'CHECK_INITIATE': 0.1652152883816802},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL.BET.CALL': {},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL.BET.FOLD': {},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL.BET.RAISE': {'CALL': 0.9999446175510314,
#   'FOLD': 5.5382448968715076e-05},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET': {'CALL': 0.0001865542515018708,
#   'FOLD': 0.0001865542515018708,
#   'RAISE': 0.9996268914969964},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.5.CHECK_INITIATE.BET.RAISE.CALL.CHECK_INITIATE.CHECK_RESPONSE': {},
#  '.5.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE': {'BET': 0.20070304746038922,
#   'CHECK_INITIATE': 0.7992969525396109},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE.BET.CALL': {},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE.BET.FOLD': {},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE.BET.RAISE': {'CALL': 0.999669749856671,
#   'FOLD': 0.0003302501433290334},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET': {'CALL': 5.528375904163317e-05,
#   'FOLD': 5.528375904163317e-05,
#   'RAISE': 0.9998894324819166},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.CALL': {},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.BET.RAISE.FOLD': {},
#  '.5.CHECK_INITIATE.CHECK_RESPONSE.CHECK_INITIATE.CHECK_RESPONSE': {}}

# %% [markdown]
# # Get some stats

# %%
def get_aggression(bots):
    results = []
    
    for b in bots:
        g = b.root.max_hand_strength
        d = b.root.max_turns
        
        for i in range(1,g+1):
            p1 = b.nash_equilibrium[f'.{i}.']['BET']
            p2 = b.nash_equilibrium[f'.{i}.CHECK_INITIATE']['BET']
            p3 = b.nash_equilibrium[f'.{i}.BET']['RAISE']
            p4 = b.nash_equilibrium[f'.{i}.CHECK_INITIATE.BET']['RAISE']
            results.append([g,d,i,p1,"Initial bet"])
            results.append([g,d,i,p2,"Bet after check"])
            results.append([g,d,i,p3,"Raise after bet"])
            results.append([g,d,i,p4,"Check-raise"])
            
    return results

# %%
pd.DataFrame(get_aggression([chance_sampling_cfr]))
# Out:
#     0  1  2         3                4
# 0   5  2  1  0.457904      Initial bet
# 1   5  2  1  0.641648  Bet after check
# 2   5  2  1  0.018618  Raise after bet
# 3   5  2  1  0.001681      Check-raise
# 4   5  2  2  0.029440      Initial bet
# 5   5  2  2  0.039576  Bet after check
# 6   5  2  2  0.007424  Raise after bet
# 7   5  2  2  0.026199      Check-raise
# 8   5  2  3  0.014646      Initial bet
# 9   5  2  3  0.002839  Bet after check
# 10  5  2  3  0.002946  Raise after bet
# 11  5  2  3  0.001968      Check-raise
# 12  5  2  4  0.026471      Initial bet
# 13  5  2  4  0.207975  Bet after check
# 14  5  2  4  0.005961  Raise after bet
# 15  5  2  4  0.001138      Check-raise
# 16  5  2  5  0.809064      Initial bet
# 17  5  2  5  0.968444  Bet after check
# 18  5  2  5  0.060766  Raise after bet
# 19  5  2  5  0.477891      Check-raise
